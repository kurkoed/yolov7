# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git

# %%
# make sure you use Tesla K80 GPU (12GB), by changing 'runtmie type' 
# !nvidia-smi
# Out:
# Tue Nov  8 05:39:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python /content/gdrive/MyDrive/yolov7/train.py --workers 8 --device 0 --batch-size 16 --data /content/gdrive/MyDrive/yolov7/data/custom.yaml --img 640 --cfg /content/gdrive/MyDrive/yolov7/cfg/training/yolov7-e6e.yaml  --weight '' --name yolov7x --hyp /content/gdrive/MyDrive/yolov7/data/hyp.scratch.p6.yaml
# Out:
# YOLOR 🚀 2022-10-29 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='/content/gdrive/MyDrive/yolov7/cfg/training/yolov7-e6e.yaml', data='/content/gdrive/MyDrive/yolov7/data/custom.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='/content/gdrive/MyDrive/yolov7/data/hyp.scratch.p6.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7x', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7x21', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !pip install -r requirements.txt

# %%
cd /content/gdrive/MyDrive/yolov7
# Out:
# /content/gdrive/.shortcut-targets-by-id/1qum2bzylNYWxvg_FD-c_6xTDpOFdkMuU/yolov7

# %%
# !python detect.py --source /content/gdrive/MyDrive/yolov7/custom_dataset/test/test.jpg --weights /content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/gdrive/MyDrive/yolov7/custom_dataset/test/test.jpg', update=False, view_img=False, weights=['/content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# Input image
from IPython.display import Image
Image(filename='/content/gdrive/MyDrive/yolov7/custom_dataset/test/test.jpg', width=640)

# %%
# Output image
from IPython.display import Image
Image(filename='/content/gdrive/MyDrive/yolov7/runs/detect/exp/test.jpg', width=640)

# %%
# !python detect.py --source /content/gdrive/MyDrive/yolov7/custom_dataset/test/test2.jpg --weights /content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/gdrive/MyDrive/yolov7/custom_dataset/test/test2.jpg', update=False, view_img=False, weights=['/content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# Input image
from IPython.display import Image
Image(filename='/content/gdrive/MyDrive/yolov7/custom_dataset/test/test2.jpg', width=640)

# %%
# Output image
from IPython.display import Image
Image(filename='/content/gdrive/MyDrive/yolov7/runs/detect/exp2/test2.jpg', width=640)

# %%
# !python detect.py --source /content/gdrive/MyDrive/yolov7/custom_dataset/test/video_2022-10-31_23-50-29.mp4 --weights /content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/gdrive/MyDrive/yolov7/custom_dataset/test/video_2022-10-31_23-50-29.mp4', update=False, view_img=False, weights=['/content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
from IPython.display import Video

Video('/content/gdrive/MyDrive/yolov7/custom_dataset/test/video_2022-10-31_23-50-29.mp4')
# Out:
# <video src="/content/gdrive/MyDrive/yolov7/custom_dataset/test/video_2022-10-31_23-50-29.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video

Video('/content/gdrive/MyDrive/yolov7/runs/detect/exp3/video_2022-10-31_23-50-29.mp4')
# Out:
# <video src="/content/gdrive/MyDrive/yolov7/runs/detect/exp3/video_2022-10-31_23-50-29.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !python detect.py --source /content/gdrive/MyDrive/yolov7/custom_dataset/test/video2.mp4 --weights /content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/gdrive/MyDrive/yolov7/custom_dataset/test/video2.mp4', update=False, view_img=False, weights=['/content/gdrive/MyDrive/yolov7/runs/train/yolov7x18/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.12.1+cu113 CUDA:0 (A100-SXM4-40GB, 40536.1875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
